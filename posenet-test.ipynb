# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import cv2

# Load PoseNet model
model = hub.load("https://tfhub.dev/google/posenet/mobilenet_v1/100")

# Load and preprocess an image
image = cv2.imread("Yoga poses.v4i.yolov8/test/images/test1.jpg")  # Replace with your image path
image = cv2.resize(image, (640, 480))
image = image / 255.0
image = np.expand_dims(image, axis=0)

# Run the model
keypoints = model(image)

# Extract keypoints
keypoints = keypoints["output_0"].numpy()

# Visualize keypoints
for i in range(keypoints.shape[1]):
    x, y = int(keypoints[0, i, 0] * image.shape[1]), int(keypoints[0, i, 1] * image.shape[0])
    cv2.circle(image, (x, y), 5, (0, 255, 0), -1)

cv2.imshow("PoseNet", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/lib/python3.8/tarfile.py:187, in nti(s)
#     186     s = nts(s, "ascii", "strict")
# --> 187     n = int(s.strip() or "0", 8)
#     188 except ValueError:
#
# ValueError: invalid literal for int() with base 8: 'ts" cont'
#
# During handling of the above exception, another exception occurred:
#
# InvalidHeaderError                        Traceback (most recent call last)
# File /usr/lib/python3.8/tarfile.py:2318, in TarFile.next(self)
#    2317 try:
# -> 2318     tarinfo = self.tarinfo.fromtarfile(self)
#    2319 except EOFHeaderError as e:
#
# File /usr/lib/python3.8/tarfile.py:1105, in TarInfo.fromtarfile(cls, tarfile)
#    1104 buf = tarfile.fileobj.read(BLOCKSIZE)
# -> 1105 obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#    1106 obj.offset = tarfile.fileobj.tell() - BLOCKSIZE
#
# File /usr/lib/python3.8/tarfile.py:1047, in TarInfo.frombuf(cls, buf, encoding, errors)
#    1045     raise EOFHeaderError("end of file header")
# -> 1047 chksum = nti(buf[148:156])
#    1048 if chksum not in calc_chksums(buf):
#
# File /usr/lib/python3.8/tarfile.py:189, in nti(s)
#     188     except ValueError:
# --> 189         raise InvalidHeaderError("invalid header")
#     190 return n
#
# InvalidHeaderError: invalid header
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/resolver.py:192, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     191 try:
# --> 192   file_utils.extract_tarfile_to_destination(
#     193       fileobj, dst_path, log_function=self._log_progress)
#     194   total_size_str = tf_utils.bytes_to_readable_str(
#     195       self._total_bytes_downloaded, True)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/file_utils.py:47, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      46 """Extract a tarfile. Optional: log the progress."""
# ---> 47 with tarfile.open(mode="r|*", fileobj=fileobj) as tgz:
#      48   for tarinfo in tgz:
#
# File /usr/lib/python3.8/tarfile.py:1633, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1632 try:
# -> 1633     t = cls(name, filemode, stream, **kwargs)
#    1634 except:
#
# File /usr/lib/python3.8/tarfile.py:1514, in TarFile.__init__(self, name, mode, fileobj, format, tarinfo, dereference, ignore_zeros, encoding, errors, pax_headers, debug, errorlevel, copybufsize)
#    1513     self.firstmember = None
# -> 1514     self.firstmember = self.next()
#    1516 if self.mode == "a":
#    1517     # Move to the end of the archive,
#    1518     # before the first empty block.
#
# File /usr/lib/python3.8/tarfile.py:2330, in TarFile.next(self)
#    2329     elif self.offset == 0:
# -> 2330         raise ReadError(str(e))
#    2331 except EmptyHeaderError:
#
# ReadError: invalid header
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 7
#       4 import cv2
#       6 # Load PoseNet model
# ----> 7 model = hub.load("https://tfhub.dev/google/posenet/mobilenet_v1/100")
#       9 # Load and preprocess an image
#      10 image = cv2.imread("Yoga poses.v4i.yolov8/test/images/test1.jpg")  # Replace with your image path
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/module_v2.py:100, in load(handle, tags, options)
#      98 if not isinstance(handle, str):
#      99   raise ValueError("Expected a string, got %s" % handle)
# --> 100 module_path = resolve(handle)
#     101 is_hub_module_v1 = tf.io.gfile.exists(_get_module_proto_path(module_path))
#     102 if tags is None and is_hub_module_v1:
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/module_v2.py:55, in resolve(handle)
#      31 def resolve(handle):
#      32   """Resolves a module handle into a path.
#      33
#      34   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      53     A string representing the Module path.
#      54   """
# ---> 55   return registry.resolver(handle)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/registry.py:49, in MultiImplRegister.__call__(self, *args, **kwargs)
#      47 for impl in reversed(self._impls):
#      48   if impl.is_supported(*args, **kwargs):
# ---> 49     return impl(*args, **kwargs)
#      50   else:
#      51     fails.append(type(impl).__name__)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/compressed_module_resolver.py:81, in HttpCompressedFileResolver.__call__(self, handle)
#      77   response = self._call_urlopen(request)
#      78   return resolver.DownloadManager(handle).download_and_uncompress(
#      79       response, tmp_dir)
# ---> 81 return resolver.atomic_download(handle, download, module_dir,
#      82                                 self._lock_file_timeout_sec())
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/resolver.py:421, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     419 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     420 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 421 download_fn(handle, tmp_dir)
#     422 # Write module descriptor to capture information about which module was
#     423 # downloaded by whom and when. The file stored at the same level as a
#     424 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     429 # module caching protocol and no code in the TF-Hub library reads its
#     430 # content.
#     431 _write_module_descriptor_file(handle, module_dir)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/compressed_module_resolver.py:78, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      75 request = urllib.request.Request(
#      76     self._append_compressed_format_query(handle))
#      77 response = self._call_urlopen(request)
# ---> 78 return resolver.DownloadManager(handle).download_and_uncompress(
#      79     response, tmp_dir)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_hub/resolver.py:200, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     196   self._print_download_progress_msg(
#     197       "Downloaded %s, Total size: %s" % (self._url, total_size_str),
#     198       flush=True)
#     199 except tarfile.ReadError:
# --> 200   raise IOError("%s does not appear to be a valid module." % self._url)
#
# OSError: https://tfhub.dev/google/posenet/mobilenet_v1/100 does not appear to be a valid module.
